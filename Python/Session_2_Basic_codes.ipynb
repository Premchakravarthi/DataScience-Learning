# %%
Hyderbad=1000

# %%
True
"True"
true
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 True
#       2 "True"
# ----> 3 true
#
# NameError: name 'true' is not defined

# %%
bill amount=1000
bill_amount=1000

# %%
# A man went to hotel the bill is 1000rs
# the son requested him to pay tip 100rs
# then how much totla bill paid

bill_amount=1000
tip_amount=100
total_bill=bill_amount+tip_amount
total_bill
# write first one or two letters and enter tab
# Out:
# 1100

# %%
# WAP take three numbers find the average

# WAP calculate area of circle when radius given as 20
# assume pi=3.14 
# Formula = pi*r*r

# WAP calculate area of right angle traingle when 
# height given as 20, breadth given as 50
# Formual= 1/2*breadth*height

# Wap Calculate area of rectangle
# Formualr= length*breadth

# Wap calculate the weight in kgs when weight in pounds
# one pound= 2.2kgs

# Wap calculate the money in rupees when money in dollars
# one dollar= 90rs

# Wap ask the user calculate tax amount for a given salary 100000 and tax percenatge is 10

# %%
# WAP take three numbers find the average
a=100
b=200
c=300
avg=(a+b+c)/3
avg

# The mistake here is brackets
# Out:
# 200.0

# %%
# WAP calculate area of circle when radius given as 20
# assume pi=3.14 
# Formula = pi*r*r
radius=20
pi=3.14
area_of_circle=pi*radius*radius
area_of_circle
# Out:
# 1256.0

# %%
# WAP calculate area of right angle traingle when 
# height given as 20, breadth given as 50
# Formual= 1/2*breadth*height

height=20
breadth=50
area_of_triangle=0.5*breadth*height
area_of_triangle
# Out:
# 500.0

# %%
# Wap calculate the weight in kgs when weight in pounds
# 1kg= 2.2pounds

# A person says i have 100 pounds 
# you need to say how much in kgs

weight_in_pounds=100
one_pound_in_kgs=2.2
weight_in_kgs=weight_in_pounds/one_pound_in_kgs
weight_in_kgs
# Out:
# 45.45454545454545

# %%
# Wap calculate the money in rupees when money in dollars
# one dollar= 90rs
money_in_dollars=100
one_dollar_in_rs=90
money_in_rupees=money_in_dollars*one_dollar_in_rs
money_in_rupees
# Out:
# 9000

# %%
# Wap ask the user calculate tax amount for a given salary 100000 and tax percenatge is 10
salary=100000
tax_per=10
#tax=10%
tax_amount=salary*tax_per/100
tax_amount
# Out:
# 10000.0
