# %%
n1=10  # w
n2=20  # w
n1,n2=30 #  f
n1,n2=20,30 # works
n1=10,20 # works
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 n1=10  # w
#       2 n2=20  # w
# ----> 3 n1,n2=30 #  f
#       4 n1,n2=20,30 # works
#       5 n1=10,20 # works
#
# TypeError: cannot unpack non-iterable int object

# %%
123number=500
123number
# Out:
#   Cell In[2], line 1
#     123number=500
#       ^
# SyntaxError: invalid decimal literal

# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %% [markdown]
# **package error**

# %%
import virat
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import virat
#
# ModuleNotFoundError: No module named 'virat'

# %%
import random

# %%
random.dhoni

#module 'random' has no attribute 'dhoni'
#uncle random has no kid name dhoni
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 random.dhoni
#
# AttributeError: module 'random' has no attribute 'dhoni'

# %%
import math

# %%
math.pow
# Out:
# <function math.pow(x, y, /)>

# %% [markdown]
# **conditional errors (11-02-26)**

# %%
if True:
print('hello')
# Out:
#   Cell In[7], line 2
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %%
a = 10
  b = 20
# Out:
#   Cell In[8], line 2
#     b = 20
#     ^
# IndentationError: unexpected indent

# %%
if True:
    print('help')            #here colon is there above, so it is CORRECT
        print('mistake')     #if there is no colon before than no gap should be provided, ERROR
# Out:
#   Cell In[9], line 3
#     print('mistake')     #if there is no colon before than no gap should be provided, ERROR
#     ^
# IndentationError: unexpected indent

# %%
if True
print('hello')
# Out:
#   Cell In[10], line 1
#     if True
#            ^
# SyntaxError: expected ':'

# %% [markdown]
# **indentation error (12-02-26)**

# %%
if True:
print('hello')
# Out:
#   Cell In[2], line 2
#     print('hello')
#     ^
# IndentationError: expected an indented block after 'if' statement on line 1

# %% [markdown]
# - indentation error is also a syntax error.

# %% [markdown]
# **AI Class Error**

# %%
import google.generativeai as genai
# Out:
# C:\Users\HP LAP\AppData\Local\Temp\ipykernel_5212\613638648.py:1: FutureWarning:
#
# All support for the `google.generativeai` package has ended. It will no longer be receiving
# updates or bug fixes. Please switch to the `google.genai` package as soon as possible.
# See README for more details:
#
# https://github.com/google-gemini/deprecated-generative-ai-python/blob/main/README.md
#
#   import google.generativeai as genai

# %% [markdown]
# **Zero division error**
# - (18-02-26)

# %%
n1 = eval(input("enter number 1:"))
n2 = eval(input("enter number 2:"))
print("Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division")
operation = eval(input("choose operation:"))
if operation == 1:
    print(f"addition of two numbers are: {n1 + n2}")
elif operation == 2:
    print(f"addition of two numbers are: {n1 - n2}")
elif operation == 3:
    print(f"addition of two numbers are: {n1 * n2}")
elif operation == 4:
    print(f"addition of two numbers are: {n1 / n2}")
else:
    print("Enter a valid operation number, try again!")
# Out:
# enter number 1: 100
# enter number 2: 0
# Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division
# choose operation: 4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[1], line 12
#      10     print(f"addition of two numbers are: {n1 * n2}")
#      11 elif operation == 4:
# ---> 12     print(f"addition of two numbers are: {n1 / n2}")
#      13 else:
#      14     print("Enter a valid operation number, try again!")
#
# ZeroDivisionError: division by zero

# %%
addition1()

def addition1():
    n1 = eval(input("enter a number:"))
    n2 = eval(input("enter a number:"))
    add = n1+n2
    print(f"the addition of {n1} and {n2} is {add}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 addition1()
#       3 def addition1():
#       4     n1 = eval(input("enter a number:"))
#
# NameError: name 'addition1' is not defined
