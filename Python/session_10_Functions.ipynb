# %% [markdown]
# #

# %% [markdown]
# **Functions**
#
# - Reuse of a block of code
#
# - functions with out arguments
#
# - functions with arguments
#
# - functions default arguments
#
# - functions with return statements
#
# - Global vs local variable
#
# - Functions in functions
#
# - Kwargs vs args

# %% [markdown]
# **1.Functions with out arguments**

# %%
def <NAME OF THE FUNCTIONS>():
    <WRITE YOUR CODE HERE>

# %%
n1 = eval(input('Enter a number:'))
n2 = eval(input("Enter a number:"))
add = n1+n2
print(f"the addition of {n1} and {n2} =",add)
# Out:
# Enter a number: 400
# Enter a number: 300
# the addition of 400 and 300 = 700

# %%
def addition():
    n1 = eval(input('Enter a number:'))
    n2 = eval(input("Enter a number:"))
    add = n1+n2
    print(f"the addition of {n1} and {n2} =",add)

# %%
addition()
# Out:
# Enter a number: 4500
# Enter a number: 3095
# the addition of 4500 and 3095 = 7595

# %% [markdown]
# - function name should not be any variable name.
#
# - functiona name should not be any current file name.
#
# - function name should not be packages names, attribute name.
#
# - no two functions should not have same name
#
# - remaining all rules are same as **variable names**

# %%
import math
def Area_of_circle():
    PI = math.pi
    radius = eval(input("Enter radius:"))
    print(PI * radius * radius)

print('hi')
Area_of_circle()
print('hello')
# Out:
# hi
# Enter radius: 90
# 25446.900494077327
# hello

# %%
Area_of_circle()
# Out:
# Enter radius: 43
# 5808.804816487527

# %%
addition1()

def addition1():
    n1 = eval(input("enter a number:"))
    n2 = eval(input("enter a number:"))
    add = n1+n2
    print(f"the addition of {n1} and {n2} is {add}.")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 addition1()
#       3 def addition1():
#       4     n1 = eval(input("enter a number:"))
#
# NameError: name 'addition1' is not defined

# %%
#calculate the tax
salary = eval(input("enter salary:"))
tax_per = eval(input("enter tax percentage:"))
tax_amount = salary * tax_per /100
print(f"the total tax amount is:{tax_amount}")
# Out:
# enter salary: 40000
# enter tax percentage: 5
# the total tax amount is:2000.0

# %%
# GIVE ALL THE VARIABLES IN LOWERCASE
#FUNCTUON NAME IN THE UPPER CASE...

def TAX():
    salary = eval(input("enter salary:"))
    tax_per = eval(input("enter tax percentage:"))
    tax_amount = salary * tax_per /100
    print(f"the total tax amount is:{tax_amount}")

# %% [markdown]
# - When we run the function we did not see any output
#
# - until unless we need to call the function.

# %%
TAX()
# Out:
# enter salary: 60000
# enter tax percentage: 4
# the total tax amount is:2400.0

# %%
TAX1()

def TAX1():
    salary1 = eval(input("enter salary:"))
    tax_per1 = eval(input("enter tax percentage:"))
    tax_amount1 = salary1 * tax_per1 /100
    print(f"the total tax amount is:{tax_amount}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 TAX1()
#       3 def TAX1():
#       4     salary1 = eval(input("enter salary:"))
#
# NameError: name 'TAX1' is not defined

# %% [markdown]
# -  Call the function after define only.
# - Once you define you can call the name at any place.

# %%
def TAX2():
    salary2 = eval(input("enter salary:"))
    tax_per2 = eval(input("enter tax percentage:"))
    tax_amount2 = income * tax_per2 /100                 #HERE WE HAVE CHANGED THE VARIABLE FROM SALARY2 AS INCOME
    print(f"the total tax amount is:{tax_amount}")

# %%
TAX2()
# Out:
# enter salary: 30
# enter tax percentage: 2
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 TAX2()
#
# Cell In[9], line 4, in TAX2()
#       2 salary2 = eval(input("enter salary:"))
#       3 tax_per2 = eval(input("enter tax percentage:"))
# ----> 4 tax_amount2 = income * tax_per2 /100                 #HERE WE HAVE CHANGED THE VARIABLE FROM SALARY2 AS INCOME
#       5 print(f"the total tax amount is:{tax_amount}")
#
# NameError: name 'income' is not defined

# %% [markdown]
# - here the TAX2() will run the code when it gets called and like it will check each and every line where the error occurs there it will show the error.

# %%
def addition():
    n1 = eval(input("enter a number:"))
    n2 = eval(input("enter a number:"))
    add = n111 + n2
    print(f"addition of {n1} and {n2} is: {add}")

# %%
def addition():
    n1 = eval(input("enter a number:"))
    n2 = eval(input("enter a number:"))
    add = n1 + n2
    print(f"addition of {n1} and {n2} is: {add}")

# %% [markdown]
# - When we define the function, it does not show any error or any answer.
# - until unless we call the function

# %%
addition()
# Out:
# enter a number: 499
# enter a number: 432
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 addition()
#
# Cell In[11], line 4, in addition()
#       2 n1 = eval(input("enter a number:"))
#       3 n2 = eval(input("enter a number:"))
# ----> 4 add = n111 + n2
#       5 print(f"addition of {n1} and {n2} is: {add}")
#
# NameError: name 'n111' is not defined

# %%
    n1 = eval(input("enter 1st number:"))
    n2 = eval(input("enter 2nd number:"))
    n3 = eval(input("enter 3rd number:"))
    avg = (n1+n2+n3)/3
    avg1 = round(avg,2)
    print(f"The average of{n1} and {n2} and {n3} is:{avg1}")
# Out:
# enter 1st number: 444
# enter 2nd number: 443
# enter 3rd number: 432
# The average of444 and 443 and 432 is:439.67

# %%
try:
    n1 = eval(input("enter 1st number:"))
    n2 = eval(input("enter 2nd number:"))
    n3 = eval(input("enter 3rd number:"))
    avg = (n1+n2+n3)/3
    avg1 = round(avg,2)
    print(f"The average of{n1} and {n2} and {n3} is:{avg1}")
except Exception as e:
    print(e)
# Out:
# enter 1st number: 40
# enter 2nd number: 40
# enter 3rd number: 40
# The average of40 and 40 and 40 is:40.0

# %%
#CASE_1:

try:
    def AVERAGE1():
        n1 = eval(input("enter a number:"))
        n2 = eval(inout("enter a number:"))
        n3 = eval(input("enter a number:"))
        avg = (n1+n2+n3)/3
        avg10 = round(avg,2)
        print(f'the average of {n1},{n2} and {n3} is:{avg10}')
except Exception as e:
    print(e)

# %%
AVERAGE1()
# Out:
# enter a number: 40
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 AVERAGE1()
#
# Cell In[16], line 6, in AVERAGE1()
#       4 def AVERAGE1():
#       5     n1 = eval(input("enter a number:"))
# ----> 6     n2 = eval(inout("enter a number:"))
#       7     n3 = eval(input("enter a number:"))
#       8     avg = (n1+n2+n3)/3
#
# NameError: name 'inout' is not defined

# %%
#CASE_2:

def AVERAGE2():
    try:
        n1 = eval(input("enter a number:"))
        n2 = eval(input("enter a number:"))
        n3 = eval(input("enter a number:"))
        avg2 = (n1+n2+n3)/3
        avg20 = round(avg2,2)
        print(f'the average of {n1},{n2} and {n3} is:{avg10}')
    except Exception as e:
        print(e)

# %%
AVERAGE2()
# Out:
# enter a number: 40
# enter a number: 20
# enter a number: 40
# name 'avg10' is not defined

# %%
#CASE_3:

def AVERAGE3():
    try:
        n1 = eval(input("enter a number:"))
        n2 = eval(input("enter a number:"))
        n3 = eval(input("enter a number:"))
        avg2 = (n1+n2+n3)/3
        avg20 = round(avg2,2)
        print(f'the average of {n1},{n2} and {n3} is:{avg20}')
    except Exception as e:
        print(e)

# %%
def EVEN_ODD():
    try:
        n1 = eval(input("enter a number:"))
        if n1 % 2 == 0:
            print(f"{n1} is a even number")
        else:
            print(f"{n1} is a odd number")
    except Exception as e:
        print(e)

# %%
EVEN_ODD()
# Out:
# enter a number: 30
# 30 is a even number

# %%
import random
num = random.randint(1,100)
if num % 2 == 0:
    print(f"{num} is a even number")
else:
    print(f"{num} is a odd number")
# Out:
# 70 is a even number

# %%
import random
def EVEN_ODD_1():
    try:
        num = random.randint(1,100)
        if num % 2 == 0:
            print(f"{num} is a even number")
        else:
            print(f"{num} is a odd number")
    except Exception as e:
        print(e)

# %%
EVEN_ODD_1()
# Out:
# 77 is a odd number

# %%
Area_of_circle()
TAX()
addition()
AVERAGE3()
EVEN_ODD_1()
# Out:
# Enter radius: 30
# 2827.4333882308138
# enter salary: 30000
# enter tax percentage: 2
# the total tax amount is:600.0
# enter a number: 33
# enter a number: 42
# addition of 33 and 42 is: 75
# enter a number: 392
# enter a number: 23
# enter a number: 134
# the average of 392,23 and 134 is:183.0
# 40 is a even number

# %%
Area_of_circle()
TAX()
addition()
AVERAGE3()
EVEN_ODD_1()

# %% [markdown]
# - All the functions above does not have values or variables inside the bracket
#
# - this concpt is called as **functions without arguments**

# %% [markdown]
# **FUNCTIONS WITH ARGUMENTS**
# - (20-02-2026)

# %%
def AVERAGE4(N1,N2,N3):

        avg2 = (n1+n2+n3)/3
        avg20 = round(avg2,2)
        print(f'the average of {n1},{n2} and {n3} is:{avg20}')

# %%
AVERAGE3()         #EMPTY
AVERAGE4()         #(100,200,300)
# Out:
# enter a number: 2
# enter a number: 2
# enter a number: 23
# the average of 2,2 and 23 is:9.0
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 2
#       1 AVERAGE3()         #EMPTY
# ----> 2 AVERAGE4()         #(100,200,300)
#
# TypeError: AVERAGE4() missing 3 required positional arguments: 'N1', 'N2', and 'N3'

# %%
AVERAGE4(100,200,300)         #(100,200,300)
# Out:
# the average of 40,40 and 40 is:40.0

# %%
- In the above function there are total 5 variables are there
    - i.e n1, n2, n3, avg2, avg20

- in that 3 variable are input

# %%
import math
def Area_of_circle(radius):
    PI = math.pi
    print(PI * radius * radius)

# %%
Area_of_circle(40)
# Out:
# 5026.548245743669

# %%
def addition11(n1,n2):
    add = n1+n2
    print(f"the addition of {n1} and {n2} is {add}.")

# %%
addition11(20,22)
# Out:
# the addition of 20 and 22 is 42.

# %%
def TAX4(salary, tax_per):
    tax_amount = salary * tax_per /100
    print(f"the total tax amount is:{tax_amount}")

# %%
TAX4(400000,9)
# Out:
# the total tax amount is:36000.0

# %%
def EVEN_ODD_3(n1):
    if n1 % 2 == 0:
        print(f"{n1} is a even number")
    else:
        print(f"{n1} is a odd number")

# %%
EVEN_ODD_3(39)
# Out:
# 39 is a odd number

# %%
EVEN_ODD_3(float(30.3923))
# Out:
# 30.3923 is a odd number

# %%
EVEN_ODD_3(30.3923)
# Out:
# 30.3923 is a odd number
