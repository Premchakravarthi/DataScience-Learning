# %% [markdown]
# **list of errors**

# %% [markdown]
# - name error
# - type error
# - value error
# - attribute error
# - module not found error
# - zero division error
# - syntax and indentation errors are not a logical errors

# %%
prem
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 prem
#
# NameError: name 'prem' is not defined

# %%
import prem
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import prem
#
# ModuleNotFoundError: No module named 'prem'

# %%
n1 = eval(input("enter number 1:"))
n2 = eval(input("enter number 2:"))
print("Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division")
operation = eval(input("choose operation:"))
if operation == 1:
    print(f"addition of two numbers are: {n1 + n2}")
elif operation == 2:
    print(f"subtraction of two numbers are: {n1 - n2}")
elif operation == 3:
    print(f"mulitiplication of two numbers are: {n1 * n2}")
elif operation == 4:
    print(f"Division of two numbers are: {n1 / n2}")
else:
    print("Enter a valid operation number, try again!")
# Out:
# enter number 1: 50
# enter number 2: 0
# Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division
# choose operation: 4
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[4], line 12
#      10     print(f"addition of two numbers are: {n1 * n2}")
#      11 elif operation == 4:
# ---> 12     print(f"addition of two numbers are: {n1 / n2}")
#      13 else:
#      14     print("Enter a valid operation number, try again!")
#
# ZeroDivisionError: division by zero

# %%
import random
random.prem
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 import random
# ----> 2 random.prem
#
# AttributeError: module 'random' has no attribute 'prem'

# %%
n1 = eval(input("enter a number:"))
# Out:
# enter a number: hi
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 n1 = eval(input("enter a number:"))
#
# File <string>:1
#
# NameError: name 'hi' is not defined

# %%
int("apple")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 int("apple")
#
# ValueError: invalid literal for int() with base 10: 'apple'

# %%
n1 = 30
n2 = 'apple'
n3 = n1+n2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 n1 = 30
#       2 n2 = 'apple'
# ----> 3 n3 = n1+n2
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# **try and except**

# %%
try:
    a = 10
    b = 20
    c = a+b
    print(c)
except Exception as e:
    print(e)
# Out:
# 30

# %%
try:
    a = 10
    b = 20
    c = a+d
    print(c)
except Exception as e:
    print(e)
# Out:
# name 'd' is not defined

# %%
try:
    import random
    random.dhoni
except Exception as e:
    print(e)
# Out:
# module 'random' has no attribute 'dhoni'

# %%
try:
    import prem
except Exception as e:
    print(e)
# Out:
# No module named 'prem'

# %%
try:
    n1 = 40
    n2 = 'apple'
    n3 = n1+n2
except Exception as e:
    print(e)
# Out:
# unsupported operand type(s) for +: 'int' and 'str'

# %%
try:
    int('apple')
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'apple'

# %%
try:
    a = eval(input("enter a number:"))
except Exception as e:
    print(e)
# Out:
# enter a number: apple
# name 'apple' is not defined

# %%
try:
    n1 = eval(input("enter number 1:"))
    n2 = eval(input("enter number 2:"))
    print("Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division")
    operation = eval(input("choose operation:"))
    if operation == 1:
        print(f"addition of two numbers are: {n1 + n2}")
    elif operation == 2:
        print(f"subtraction of two numbers are: {n1 - n2}")
    elif operation == 3:
        print(f"multiplication of two numbers are: {n1 * n2}")
    elif operation == 4:
        print(f"Division of two numbers are: {n1 / n2}")
    else:
        print("Enter a valid operation number, try again!")
        
except Exception as e:
    print(e)
# Out:
# enter number 1: 33
# enter number 2: 0
# Enter 1 for addition, 2 for subtraction, 3 for multiplication, 4 for division
# choose operation: 4
# division by zero

# %% [markdown]
# - day (19-02-26)
#
# - indentation and syntax error will not catch because, its your job to write the code properly.

# %%
#percentage program try and exception

try:
    percentage = eval(input("enter a number:"))
    if percentage >= 75:
        print('A')
        elif percentage >= 60:
        print('B')
    elif percentage >= 45:
        print('C')
    elif percentage >= 35:
        print('D')
    else:
        print('Fail')
except Exception as e:
    print(e)
# Out:
#   Cell In[6], line 7
#     elif percentage >= 60:
#     ^
# SyntaxError: invalid syntax

# %%
#try: working should be here
#except: Error will catch here 
#finally: whether code works or fail
#           this block will run

# %%
try:
    print('Coffe is good')
except Exception as e:
    print(e)
    print('Coffee is not good')
finally:
    print('OFF THE STOVE')
# Out:
# Coffe is good
# OFF THE STOVE

# %%
try:
    print(a,'Coffe is good')
except Exception as e:
    print(e)
    print('Coffee is not good')
finally:
    print('OFF THE STOVE')
# Out:
# name 'a' is not defined
# Coffee is not good
# OFF THE STOVE
