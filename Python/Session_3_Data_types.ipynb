# %% [markdown]
# - In python we have many data types
#
# -In that some are importnat inbuilt datatypes are
#
# - int (integer)
#
# - float
#
# - str (string)
#
# - bool (boolean)
#
# - complex
#
# - list
#
# - tuple
#
# - dict (dictionary)
#
# - set
#
# - frozenset
#
# - bytes
#
# - bytearray
#
# - range
#
# - None (NoneType)

# %% [markdown]
# **Integer**

# %%
n1=100
type
print
sum
max
min
len
# Out:
# <function len(obj, /)>

# %%
n1=100
type(n1)
# Out:
# int

# %% [markdown]
# **float**

# %%
n2=10.5
type(n2)
# Out:
# float

# %%
1e+1,1e+2,1e+3,1e+4
# Out:
# (10.0, 100.0, 1000.0, 10000.0)

# %%
3e+3  # 3*1000
# Out:
# 3000.0

# %%
5e+2  # 5*100
# Out:
# 500.0

# %%
print(1e-1)  # 1/10
print(1e-2)  # 1/100
print(1e-3)  # 1/1000
# Out:
# 0.1
# 0.01
# 0.001

# %%
1e-5
# Out:
# 1e-05

# %%
0.0000005
5/1000000
# Out:
# 5e-06

# %%
1e+1  # 1*10 
1e-1  # 1/10
# Out:
# 0.1

# %%
1e1,1e2,1e3
print(1e1,1e+1)
print(1e2,1e+2)
# Out:
# 10.0 10.0
# 100.0 100.0

# %%
two familys
addition         divide
+                  -
*                  /
integration       diff

# %% [markdown]
# **strings**

# %%
name1='naresh it'
type(name1)
# Out:
# str

# %%
name2="naresh it"
type(name2)
# Out:
# str

# %%
name3="python'
# Out:
#   Cell In[19], line 1
#     name3="python'
#           ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
type
print
sum
max
min
len
# Out:
# <function len(obj, /)>

# %%
name1='python'
type(name1)
# Out:
# str

# %%
print(name1)
# Out:
# python

# %%
len(name1)
# Out:
# 6

# %%
min(name1)

# 'python'
# Out:
# 'h'

# %% [markdown]
# **ASCII American Standard Code for Information Interchange**

# %%
ord
chr
# Out:
# <function chr(i, /)>

# %%
ord('A'),chr(65)
# Out:
# (65, 'A')

# %%
ord('a'),chr(97)
# Out:
# (97, 'a')

# %%
ord('p'),ord('y'),ord('t'),ord('h'),ord('o'),ord('n')
# Out:
# (112, 121, 116, 104, 111, 110)

# %%
min(name1),max(name1)
# Out:
# ('h', 'y')

# %% [markdown]
# - print only to see the answers

# %%
name1='python'
name2='python '
len(name1),len(name2)
# Out:
# (6, 7)

# %%
print(name1)
print(name2)
# Out:
# python
# python

# %%
print(len('')) # 0
print(len(' ')) # 1
print(len('a')) # 1
# Out:
# 0
# 1
# 1

# %%
sum('python')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 sum('python')
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
'p'+'y'+'t'+'h'+'o'+'n' # Concatenation
# Out:
# 'python'

# %%
0+'A'  # 'int'+'str'  Type error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 0+'A'  # 'int'+'str'  Type error
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
help(sum)
# Out:
# Help on built-in function sum in module builtins:
#
# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers
#
#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %%
0+'p'+'y'+'t'+'h'+'o'+'n'

# %%
type
print
len
max
min
sum
ord
chr
help

# %%
"I love python"
# Out:
# 'I love python'

# %%
print("I love 'python'")
# Out:
# I love 'python'

# %%
print('I love "python"') # Im printing
# Out:
# I love "python"

# %%
"hello how are you
im good"
# Out:
#   Cell In[40], line 1
#     "hello how are you
#     ^
# SyntaxError: unterminated string literal (detected at line 1)

# %% [markdown]
# **DOC STRING**
#
#     - Jupyter notebook : Markdown
#
#     - Vscode pycharm there is no markdown
#
#     - if any person writing triple quotes means
#
#     - he is trying to convey information
#
#     - triple quotes will not use for code purpose

# %%
"""hello how are you
im good"""

# DOC STRING 
# Jupyter notebook : Markdown
# Vscode pycharm
# if any person writing triple quotes means
# he is trying to convey information
# triple quotes will not use for code purpose

help(<take cursor apply shift+tab>)
sum()
# Out:
#   Cell In[42], line 11
#     help(<take cursor apply shift+tab>)
#          ^
# SyntaxError: invalid syntax

# %%
"""hello how are you
im good"""

# DOC STRING 
# Jupyter notebook : Markdown
# Vscode pycharm
# if any person writing triple quotes means
# he is trying to convey information
# triple quotes will not use for code purpose

help(<take cursor apply shift+tab>)
sum()

# %%
# Help on built-in function sum in module builtins:

# sum(iterable, /, start=0)
#     Return the sum of a 'start' value (default: 0) plus an iterable of numbers

#     When the iterable is empty, return the start value.
#     This function is intended specifically for use with numeric values and may
#     reject non-numeric types.

# %% [markdown]
# **boolean**

# %%
val=True 
type(val)
# Out:
# bool

# %%
val=False
type(val)
# Out:
# bool

# %% [markdown]
# - True indicates ON also indicates 1
#
#     - Whenever you feel something there then its ON
# - False indicates OFF also indicates 0
#
#     - Anything empty then it is OFF

# %% [markdown]
# - int
# - float
# - str
# - bool

# %% [markdown]
# **complex**

# %%
a=30+40j
type(a)
# Out:
# complex

# %%
l1=[10,110,220,330]
l2=['p','y','t','h','o','n']
l3=[110,120,330,'h','o','z']
type
print
len :4 , 6,6 
max : 330,y,<error>
min : 10,h,<error>
sum : 670,type,type
# Out:
#   Cell In[48], line 6
#     len :4 , 6,6
#            ^
# SyntaxError: invalid syntax

# %%
l1=[10,110,220,330]  has only numbers
l2=['p','y','t','h','o','n'] has only string
l3=[110,120,330,'h','o','z'] has both numbers and strings

110+'h'
