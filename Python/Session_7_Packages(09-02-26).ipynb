# %%
import addition
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import addition
#
# ModuleNotFoundError: No module named 'addition'

# %%
import random

# %%
import os

# %%
import time

# %%
import math

# %%
import cv2
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import cv2
#
# ModuleNotFoundError: No module named 'cv2'

# %% [markdown]
# **Module**
# - module means one single python file.
# - it has functions, variables, constants.
# - create one python file : math_fun.py
#     - this python file has 4 functions
#         - addition
#         - subtraction
#         - multiplication
#         - division
#
# **Package**
# - collection module
# - collection of python files
# - you can create 4 python files, each file has again function, variables, and constants.
# - addition.py
#    - func_1
# - subtract.py
#    - func_2
# - multiplication.py
#     - func_3
# - division.py
#     - func_4
#
#
# - **function means a single logic defined inside the python file/ module**
# - **method means a logic defined under the class**

# %%
import random

# %%
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
import random
dir(random)
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000174ADF59FF0>>

# %%
import <uncle>
dir(uncle)
uncle.kid
# Out:
#   Cell In[17], line 1
#     import <uncle>
#            ^
# SyntaxError: invalid syntax

# %%
# function or method == ()
# constant == no brackets

# %%
import math

# %%
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'cbrt',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'exp2',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fma',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'lcm',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'nextafter',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'sumprod',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc',
#  'ulp']

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sin
# Out:
# <function math.sin(x, /)>

# %%
import math
math.pi   #don't give brackets first. 
          # first check that is it a constant value or a function
# constant value menas == direct answer will provide
#function means == it will give the indication
# function/bound methods
#then we need to provide brackets
# Out:
# 3.141592653589793

# %% [markdown]
# - don't give brackets first.
# - first check that is it a constant value or a function
# - constant value menas == direct answer will provide
# - function means == it will give the indication
# - function/bound methods
# - then we need to provide brackets

# %%
import time
dir(time)
# Out:
# ['_STRUCT_TM_ITEMS',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'altzone',
#  'asctime',
#  'ctime',
#  'daylight',
#  'get_clock_info',
#  'gmtime',
#  'localtime',
#  'mktime',
#  'monotonic',
#  'monotonic_ns',
#  'perf_counter',
#  'perf_counter_ns',
#  'process_time',
#  'process_time_ns',
#  'sleep',
#  'strftime',
#  'strptime',
#  'struct_time',
#  'thread_time',
#  'thread_time_ns',
#  'time',
#  'time_ns',
#  'timezone',
#  'tzname']

# %%
time.sleep
# Out:
# <function time.sleep(object, /)>

# %%
pip freeze
# Out:
# aiobotocore @ file:///C:/miniconda3/conda-bld/aiobotocore_1760994335546/work
# aiodns @ file:///C:/miniconda3/conda-bld/aiodns_1762185075564/work
# aiohappyeyeballs @ file:///C:/b/abs_f806x82huz/croot/aiohappyeyeballs_1755769855628/work
# aiohttp @ file:///C:/miniconda3/conda-bld/aiohttp_1762519774760/work
# aioitertools @ file:///C:/b/abs_70vydn6fmg/croot/aioitertools_1754313763510/work
# aiosignal @ file:///C:/b/abs_84ej696pud/croot/aiosignal_1755870823775/work
# alabaster @ file:///C:/Users/dev-admin/perseverance-python-buildout/croot/alabaster_1729041938345/work
# altair @ file:///C:/b/abs_0b1avjyzoc/croot/altair_1743016738596/work
# anaconda-anon-usage @ file:///opt/miniconda3/conda-bld/anaconda-anon-usage_1764636648062/work
# anaconda-auth @ file:///C:/miniconda3/conda-bld/anaconda-cloud-auth-split_1764891486360/work
# anaconda-catalogs @ file:///C:/miniconda3/conda-bld/anaconda-catalogs_1764859031645/work
# ...

# %%
import random
dir(random)
random.randint
# Out:
# <bound method Random.randint of <random.Random object at 0x00000174ADF59FF0>>

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,10)      #ludo game, 
random.randint(1,6)
# Out:
# 5

# %%
import random
dir(random)
random.randint
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,6)
# Out:
# 4

# %%
# uncle : random
#kids : random, randint

#uncle : math
#kids : pi, e, pow, sqrt, sin

#uncle : keyword
#kids : kwlist

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
import math
math.e
# Out:
# 2.718281828459045

# %%
import math
math.pow
help(math.pow)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).

# %%
math.pow(2, 4)
# Out:
# 16.0

# %%
import math 
math.sqrt
help(math.sqrt)
# Out:
# Help on built-in function sqrt in module math:
#
# sqrt(x, /)
#     Return the square root of x.

# %%
math.sqrt(625)
# Out:
# 25.0

# %%
import math
math.sin
help(math.sin)
# Out:
# Help on built-in function sin in module math:
#
# sin(x, /)
#     Return the sine of x (measured in radians).

# %%
math.sin(90)
# Out:
# 0.8939966636005579

# %%
import keyword
keyword.kwlist
help(keyword.kwlist)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return bool(key in self).
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(self, index, /)
#  |      Return self[index].
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %% [markdown]
# **10-02-26**

# %%
import random
dir(random)
# Out:
# ['BPF',
#  'LOG4',
#  'NV_MAGICCONST',
#  'RECIP_BPF',
#  'Random',
#  'SG_MAGICCONST',
#  'SystemRandom',
#  'TWOPI',
#  '_ONE',
#  '_Sequence',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_accumulate',
#  '_acos',
#  '_bisect',
#  '_ceil',
#  '_cos',
#  '_e',
#  '_exp',
#  '_fabs',
#  '_floor',
#  '_index',
#  '_inst',
#  '_isfinite',
#  '_lgamma',
#  '_log',
#  '_log2',
#  '_os',
#  '_parse_args',
#  '_pi',
#  '_random',
#  '_repeat',
#  '_sha512',
#  '_sin',
#  '_sqrt',
#  '_test',
#  '_test_generator',
#  '_urandom',
#  'betavariate',
#  'binomialvariate',
#  'choice',
#  'choices',
#  'expovariate',
#  'gammavariate',
#  'gauss',
#  'getrandbits',
#  'getstate',
#  'lognormvariate',
#  'main',
#  'normalvariate',
#  'paretovariate',
#  'randbytes',
#  'randint',
#  'random',
#  'randrange',
#  'sample',
#  'seed',
#  'setstate',
#  'shuffle',
#  'triangular',
#  'uniform',
# ...

# %%
random.randit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 random.randit
#
# AttributeError: module 'random' has no attribute 'randit'

# %%
help(random.randint)
# Out:
# Help on method randint in module random:
#
# randint(a, b) method of random.Random instance
#     Return random integer in range [a, b], including both end points.

# %%
random.randint(1,40)
# Out:
# 13

# %% [markdown]
# **package name: random**
# - methods
#
# - randint
# - random
# - choice(provides a list of values, random.choice([10,20,30])
# - shuffle :similar string
#
# **package name: string**
# - ascii_upper_case
# - ascii_lower_case
# - punctuations
# - digits
#
# **math**
#     - pi
#     - e
#     - square
#     - sqrt
#     - pow
#     - sin

# %%
import random
dir(random)
random.randint(10,30)
help(random)
# Out:
# Help on module random:
#
# NAME
#     random - Random variable generators.
#
# MODULE REFERENCE
#     https://docs.python.org/3.13/library/random.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#         bytes
#         -----
#                uniform bytes (values between 0 and 255)
#
#         integers
#         --------
#                uniform within range
#
#         sequences
#         ---------
#                pick random element
#                pick random sample
#                pick weighted random sample
#                generate random permutation
#
#         distributions on the real line:
#         ------------------------------
#                uniform
# ...

# %%
import random
random.randint(10,20)
# Out:
# 19

# %%
import random
random.random()
help(random.random)
# Out:
# Help on built-in function random:
#
# random() method of random.Random instance
#     random() -> x in the interval [0, 1).

# %%
random.random()
# Out:
# 0.04831363674146849

# %%
random.choice
help(random.choice)
# Out:
# Help on method choice in module random:
#
# choice(seq) method of random.Random instance
#     Choose a random element from a non-empty sequence.

# %%
random.choice([10,20,30,40])
# Out:
# 40

# %%
random.choice(['apple','ball','cat','dog','elephant','fox','giraffe'])
# Out:
# 'apple'

# %%
random.choice((10,20,30))
# Out:
# 10

# %%
x = ([10,20,30,40])
random.shuffle(x)
help(random.shuffle)
# Out:
# Help on method shuffle in module random:
#
# shuffle(x) method of random.Random instance
#     Shuffle list x in place, and return None.

# %%
x = ([10,20,30,40])
random.shuffle(x)
print(x)
# Out:
# [40, 30, 20, 10]

# %%
random.shuffle(<shift + tab>)
#alternative for the help
# Out:
#   Cell In[67], line 1
#     random.shuffle(<shift + tab>)
#                    ^
# SyntaxError: invalid syntax

# %%
random.shuffle()
#shuffle list x in place, and return None.

# %%
l = [10,20,30,40,50]
random.shuffle(l)
print(l)
#shuffle list x in place, and return none
# Out:
# [30, 10, 20, 50, 40]

# %%
l #inplace means same list only none
# Out:
# [30, 10, 20, 50, 40]

# %%
import math
math.sqrt(81)
# Out:
# 9.0

# %%
import string

# %%
string.ascii_letters
# Out:
# 'abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
string.ascii_uppercase
# Out:
# 'ABCDEFGHIJKLMNOPQRSTUVWXYZ'

# %%
string.capwords('PRem ')
# Out:
# 'Prem'

# %%
string.capwords('Prem' )
# Out:
# 'Prem'

# %%
import os

# %%
os.getcwd()
# Out:
# 'C:\\Users\\HP LAP\\Naresh IT\\Python'

# %%
os.makedirs('Python')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[108], line 1
# ----> 1 os.makedirs('Python')
#
# File C:\ProgramData\anaconda3\Lib\os.py:228, in makedirs(name, mode, exist_ok)
#     226         return
#     227 try:
# --> 228     mkdir(name, mode)
#     229 except OSError:
#     230     # Cannot rely on checking for EEXIST, since the operating system
#     231     # could give priority to other errors like EACCES or EROFS
#     232     if not exist_ok or not path.isdir(name):
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Python'

# %%
os.makedirs('packages',exist_ok = True)

# %%
os.makedirs('Prem')

# %%
import wordcloud
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[112], line 1
# ----> 1 import wordcloud
#
# ModuleNotFoundError: No module named 'wordcloud'

# %% [markdown]
# - module not found wordcloud means
# - wordcloud package is not installed in my laptop
# - i need to install now
#
# - i can install in 2 places
# - 1.Anaconda prompt(most recomended)
# - 2.in same jupyter notebook
# - internet connection should be there
# - if no internet we will see HTTP error
#
# **syntax**
# - pip install YOURMODULENAME
# - OPEN GOOGLE CHROME

# %%
import cv2

# %%
# !pip freeze
# Out:
# aiobotocore @ file:///C:/miniconda3/conda-bld/aiobotocore_1760994335546/work
# aiodns @ file:///C:/miniconda3/conda-bld/aiodns_1762185075564/work
# aiohappyeyeballs @ file:///C:/b/abs_f806x82huz/croot/aiohappyeyeballs_1755769855628/work
# aiohttp @ file:///C:/miniconda3/conda-bld/aiohttp_1762519774760/work
# aioitertools @ file:///C:/b/abs_70vydn6fmg/croot/aioitertools_1754313763510/work
# aiosignal @ file:///C:/b/abs_84ej696pud/croot/aiosignal_1755870823775/work
# alabaster @ file:///C:/Users/dev-admin/perseverance-python-buildout/croot/alabaster_1729041938345/work
# altair @ file:///C:/b/abs_0b1avjyzoc/croot/altair_1743016738596/work
# anaconda-anon-usage @ file:///opt/miniconda3/conda-bld/anaconda-anon-usage_1764636648062/work
# anaconda-auth @ file:///C:/miniconda3/conda-bld/anaconda-cloud-auth-split_1764891486360/work
# anaconda-catalogs @ file:///C:/miniconda3/conda-bld/anaconda-catalogs_1764859031645/work
# ...

# %%
cv2.numpy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 cv2.numpy
#
# NameError: name 'cv2' is not defined
