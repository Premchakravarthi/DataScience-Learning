# %% [markdown]
# **print Statements**

# %% [markdown]
# - print statements are used to see the answers
# - print statements are useed to represent answers in a structured and good way.
# - print is not a logic, it is used, just to display.

# %%
10
20
# Out:
# 20

# %%
print(10)
print(20)
# Out:
# 10
# 20

# %%
10,20
# Out:
# (10, 20)

# %%
10,20,'apple'
# Out:
# (10, 20, 'apple')

# %%
print(10,20,'apple')
# Out:
# 10 20 apple

# %%
print('my name is:','Prem')
print('I am studying at:', 'Naresh IT')
# Out:
# my name is: Prem
# I am studying at: Naresh IT

# %%
# where to print the values using the variables
institue_name = 'Naresh IT'
print('My name is:', 'institue_name')         #wrong
print('im studying in:', institue_name)       #correct
# Out:
# My name is: institue_name
# im studying in: Naresh IT

# %%
print('my','name',"is",":",'prem')
# Out:
# my name is : prem

# %%
#addition
n1 = eval(input('Enter a number:'))
n2 = eval(input('Enter a number:'))
sum = n1 +n2
sum
# Out:
# Enter a number: 200
# Enter a number: 300
# 500

# %%
print('the addition of 100 and 200 is: sum')
print('the addition of 100 and 200 is: 300')
print('the addition of', n1,'and',n2,'is:',sum)
# Out:
# the addition of 100 and 200 is: sum
# the addition of 100 and 200 is: 300
# the addition of 200 and 300 is: 500

# %%
print(sum)
# Out:
# 500

# %%
n1 = 1000
n2 = 2000
add = n1+n2
print('addition of 100 and 200 is: 300')
print('addition of',n1,'and',n2,'is:',add)
# Out:
# addition of 100 and 200 is: 300
# addition of 1000 and 2000 is: 3000

# %%
#take your name, city, age
name = 'Prem'
city = 'Nellore'
Age = 23
print("My name is", name, 'im from', city,', im', Age,'years old')
# Out:
# My name is Prem im from Nellore , im 23 years old

# %% [markdown]
# **Format Method**

# %%
n1 = 1000
n2 = 2000
add = n1 + n2
#fix your writeup
print('the addition of 1000 and 2000 is: 3000')
print('the addition of {} and {} is:{}')
print('the addition of {} and {} is: {}'.format(n1, n2, add))      #correct
# Out:
# the addition of 1000 and 2000 is: 3000
# the addition of {} and {} is:{}
# the addition of 1000 and 2000 is: 3000

# %%
print('My name is {} im from {}, and im {} years old.'.format(name,city,Age))
# Out:
# My name is Prem im from Nellore, and im 23 years old.

# %%
#avg of 3 number
n1 = eval(input('enter a number:'))
n2 = eval(input('enter a number:'))
n3 = eval(input('enter a number:'))
avg = (n1+n2+n3)/3
print('the avg of{},{},{} is {}.'.format(n1,n2,n3,avg))
# Out:
# enter a number: 10
# enter a number: 20
# enter a number: 30
# the avg of10,20,30 is 20.0.

# %% [markdown]
# **fsting**

# %%
n1 = 1000
n2 = 2000
add = n1 + n2
#fix your write-up
print('the addition of 1000 and 2000 is: 3000')
print('the addition of {} and {} is:{}')
print('the addition of {} and {} is: {}'.format(n1, n2, add))      #correct
print('the addition of {n1} and {n2} is:{add}')
print(f'the addition of {n1} and {n2} is:{add}')                   #FORMAT METHOD USAGE (METHOD 3)
# Out:
# the addition of 1000 and 2000 is: 3000
# the addition of {} and {} is:{}
# the addition of 1000 and 2000 is: 3000
# the addition of {n1} and {n2} is:{add}
# the addition of 1000 and 2000 is:3000

# %%
dollar = 100
rupees = 100 * 90
print('9000rs')
print('rupeesrs')
print(rupees)
print(rupees,'rs')
print('{}rs'.format(rupees))
print(f'{rupees}rs')            #3RD METHOD AND MOST USAGE
print(f'{rupees}$')
# Out:
# 9000rs
# rupeesrs
# 9000
# 9000 rs
# 9000rs
# 9000rs
# 9000$
